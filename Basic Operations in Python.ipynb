# %%
def is_word_there(text, word):
    
    """ your code goes in here
    return return 1 if word is in the text.
    return -1 if word is not in the text
    """
    #read file and store in variable 'data'
    with open(text, 'r') as file:
        data = file.read().lower()
    
    #check if 'word' exists in the data
    if word.lower() in data:
        return 1
    return -1
    
def count_word(text, word):
    
    """your code goes in here
    return the number of word counts in a text.
    if the word does not in the text, return -1.
    for example, the text is 'I like to play football. 
    I also like to watch football. My favorite football team is Eagles.'
    let's say your word is football. the function should return 3.
    """
    #read file and store in varibale data
    data = open(text).read().lower()
    #count the number of times 'word' appears in 'data'
    count = data.count(word.lower())
    if(count > 0):
        return count
    return -1

def get_sum(numbers):
    
    """
    given a list of numbers. find the sum
    Do not use the Python function sum

    """
    count = 0
    #iterating over all values in numbers
    for i in numbers:
        count += i

    return count
    
def get_factorial(number):
    
    """
    given a number, find its factorial such as 5! = 20
    Do not use a python built-in function - code it
    
    """
    factorial = 1
    while(number > 1):
        factorial = factorial * number
        number -= 1

    return factorial
    
def sum_lists(list1, list2):
    
    """
    given that list1 and list 2 are equal sizes.
    get the sum of these two lists elementwise
    for example:
    list1 = [1, 6, 12]
    list2 = [4, 2, 14]
    your sum should return
    [5, 8, 26]
    """
    result = []
    
    for i in range(len(list1)):
        result.append(list1[i] + list2[i])

    return result
    
def isEven(number):  

    """
    determine if a number is even
    if even, return +1
    if odd, return -1 
    """
    #number is even if after dividing it by 2, remainder is 0
    if(number % 2 == 0):
        return 1
    else:
        return -1

def isOdd(number):
        
    """
    
    determine if a number is odd
    if odd, return +1
    if not return -1
    
    """
     #isOdd function works in a opposite fashion to isEven. Here instead of re-writing the code, using previously defined function
    if isEven(number) == -1:
        return 1
    else:
        return -1

# %%
# Test Cases
if __name__ == '__main__':
    
    # question 1 test cases
    if is_word_there('text.txt', 'drexel') == 1:
        print('you have passed question 1 test 1')
    else:
        print('you have failed question 1 test 1')
        
    if is_word_there('text.txt', 'university') == 1:
        print('you have passed question 1 test 2')
    else:
        print('you have failed question 1 test 2')
        
    if is_word_there('text.txt', 'large') == -1:
        print('you have passed question 1 test 3')
    else:
        print('you have failed question 1 test 3')

        
    # question 2 test cases
    if count_word('text.txt', 'Drexel') == 6:
        print('you have passed question 2 test 1')
    else:
        print('you have failed question 2 test 1')
        
    if count_word('text.txt', 'university') == 5:
        print('you have passed question 2 test 2')
    else:
        print('you have failed question 2 test 2')
        
    if count_word('text.txt', 'education') == 1:
        print('you have passed question 2 test 3')
    else:
        print('you have failed question 2 test 3')
 

    # question 3 test cases
    if get_sum([4, 5, 8, 12, 9, 20]) == 58:
        print('you have passed question 3 test 1')
    else:
        print('you have failed question 3 test 1')
        
    if get_sum([-10, -5, 100]) == 85:
        print ('you have passed question 3 test 2')
    else:
        print('you have failed question 3 test 2')
       
        
    # question 4 test cases
    if get_factorial(5) == 120:
        print('you have passed question 4 test 1')
    else:
        print('you have failed question 4 test 1')
        
    if get_factorial(10) == 3628800:
        print('you have passed question 4 test 2')
    else:
        print('you have failed question 4 test 2')       
        

     # question 5 test cases
    if sum_lists([5, 6, 8, 10], [10, 12, 18, -8]) == [15, 18, 26, 2]:
        print('you have passed question 5 test 1')
    else:
        print('you have failed question 5 test 1')
        
    if sum_lists([13, 12, -800, 10, 7], [-10, 22, 18, -8, -65]) == [3, 34, -782, 2, -58]:
        print('you have passed question 5 test 2')
    else:
        print('you have failed question 5 test 2')
    
    
     # question 6 test cases
    if isEven(4) == 1:
        print('you have passed question 6 test 1')
    else:
        print('you have failed question 6 test 1')
    if isEven(11) == -1:
        print('you have passed question 6 test 2')
    else:
        print('you have failed question 6 test 2')


     # question 7 test cases
    if isOdd(7) == 1:
        print('you have passed question 7 test 1')
    else:
        print('you have failed question 7 test 1')
    if isOdd(12) == -1:
        print('you have passed question 7 test 2')
    else:
        print('you have failed question 7 test 2')
# Out:
# you have passed question 1 test 1
# you have passed question 1 test 2
# you have passed question 1 test 3
# you have passed question 2 test 1
# you have passed question 2 test 2
# you have passed question 2 test 3
# you have passed question 3 test 1
# you have passed question 3 test 2
# you have passed question 4 test 1
# you have passed question 4 test 2
# you have passed question 5 test 1
# you have passed question 5 test 2
# you have passed question 6 test 1
# you have passed question 6 test 2
# you have passed question 7 test 1
# you have passed question 7 test 2
